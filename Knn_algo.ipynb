# %% [markdown]
# <a href="https://colab.research.google.com/github/SONU00011/data-science-linear-algorithm/blob/main/Knn_algo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("/content/gym_members_exercise_tracking.csv")
print(df)
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
from sklearn  import preprocessing
le = preprocessing.LabelEncoder()
df["Gender"] = le.fit_transform(df["Gender"])
print(df)
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56       1         88.3        1.71      180      157           60
# 1     46       0         74.9        1.53      179      151           66
# 2     32       0         68.1        1.66      167      122           54
# 3     25       1         53.2        1.70      190      164           56
# 4     38       1         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24       1         87.1        1.74      187      158           67
# 969   25       1         66.6        1.61      184      166           56
# 970   59       0         60.4        1.76      194      120           53
# 971   32       1        126.4        1.83      198      146           62
# 972   46       1         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
x = df[["Age","Gender","Weight (kg)","Height (m)","Max_BPM","Avg_BPM","Resting_BPM"]].values
y =df["BMI"].values
print(x)
print(y
      )
# Out:
# [[ 56.    1.   88.3 ... 180.  157.   60. ]
#  [ 46.    0.   74.9 ... 179.  151.   66. ]
#  [ 32.    0.   68.1 ... 167.  122.   54. ]
#  ...
#  [ 59.    0.   60.4 ... 194.  120.   53. ]
#  [ 32.    1.  126.4 ... 198.  146.   62. ]
#  [ 46.    1.   88.7 ... 166.  146.   66. ]]
# [30.2  32.   24.71 18.41 14.39 20.55 23.76 30.57 32.34 30.07 43.31 17.89
#  43.4  23.62 35.93 13.88 27.34 13.98 21.81 26.96 28.41 22.95 25.16 38.16
#  22.51 21.78 20.12 17.6  24.54 27.64 33.4  28.31 19.37 25.83 27.84 42.63
#  24.37 33.14 19.11 17.77 21.4  17.3  33.8  23.93 40.1  15.31 18.07 23.17
#  20.42 33.61 19.43 27.18 34.18 32.69 22.78 44.84 28.35 21.77 20.86 16.99
#  22.45 16.86 32.93 17.11 22.28 25.89 33.55 20.88 19.72 39.12 27.7  25.89
#  15.24 21.88 35.86 16.76 18.15 21.58 33.16 24.72 17.27 19.65 23.53 28.87
#  21.53 19.42 29.71 22.89 29.61 29.53 31.44 21.53 27.85 22.31 30.3  22.15
#  40.71 37.56 26.05 18.76 29.61 15.7  22.61 34.5  18.12 17.54 18.66 23.09
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
print(y_train)
print(y_test)
# Out:
# [21.81 31.64 23.22 28.27 44.71 27.47 32.93 24.72 21.   36.29 24.16 25.49
#  15.61 25.85 30.59 22.48 24.31 32.73 24.71 25.92 20.47 26.47 25.05 19.42
#  29.83 16.76 12.67 15.14 28.05 20.71 44.66 32.34 32.   26.39 18.29 16.41
#  26.47 27.14 20.66 31.04 24.75 18.98 26.58 30.63 21.45 19.36 32.7  22.76
#  23.08 27.11 29.98 31.05 19.43 27.69 27.92 27.55 28.12 40.09 17.63 17.6
#  21.66 15.07 32.69 20.11 24.87 31.13 31.4  24.72 28.97 22.32 17.77 12.32
#  12.47 19.01 26.26 22.19 27.2  23.07 25.33 20.38 16.2  43.31 17.54 19.72
#  24.13 30.68 19.35 12.73 23.76 19.71 23.79 30.19 36.95 27.68 28.41 23.22
#  18.13 31.32 31.75 25.89 33.61 15.43 18.67 26.9  16.52 24.25 18.15 20.42
#  19.45 20.16 32.72 29.49 23.14 22.28 23.48 34.18 40.45 30.54 27.05 24.13
#  14.78 14.07 28.88 30.52 43.4  21.91 17.88 24.31 17.75 15.75 30.37 21.66
#  22.48 30.43 17.05 26.1  20.28 13.38 25.62 20.71 13.98 19.63 23.79 21.26
#  25.35 20.75 19.01 29.5  30.22 31.17 23.21 21.8  21.26 27.74 26.75 15.8
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
# Import KNeighborsRegressor instead of KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
# Create a KNeighborsRegressor object
regressor = KNeighborsRegressor(n_neighbors=5)
# Fi
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [24.366 33.004 32.72  27.834 28.57  33.4   26.404 27.078 27.316 25.944
#  25.016 25.376 35.508 19.632 15.966 22.758 22.232 31.396 24.098 18.958
#  24.242 26.222 26.254 32.742 19.846 17.274 24.938 25.634 27.382 17.668
#  25.382 15.912 24.88  24.852 39.144 18.516 28.622 18.656 17.396 17.482
#  28.392 24.382 23.362 24.63  27.916 25.086 34.49  31.756 18.088 22.678
#  26.7   18.74  25.866 16.9   29.21  24.724 26.344 21.2   23.172 24.846
#  19.69  32.33  33.098 27.27  22.138 22.176 24.472 34.838 20.982 21.424
#  24.912 25.092 23.192 29.342 17.128 19.528 26.136 21.994 22.544 18.196
#  36.672 35.508 28.026 25.084 31.32  20.276 18.596 17.084 27.306 26.494
#  23.21  20.806 26.402 19.39  23.172 24.738 37.148 20.148 20.564 21.704
#  27.944 23.846 36.434 29.362 22.406 24.836 19.35  36.598 25.706 32.016
#  18.772 29.898 16.942 29.15  14.992 22.22  37.718 23.336 24.922 26.26
#  19.554 19.998 24.09  25.228 26.074 16.834 30.178 37.586 20.748 35.538
# ...

# %%
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
# from sklearn.neighbors import KNeighborsClassifier
# classifier = KNeighborsClassifier(n_neighbors=5)
# classifier.fit(x_train, y_train)
# y_pred = classifier.predict(x_test)
# print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-28ba07440c2a> in <cell line: 4>()
#       2 from sklearn.neighbors import KNeighborsClassifier
#       3 classifier = KNeighborsClassifier(n_neighbors=5)
# ----> 4 classifier.fit(x_train, y_train)
#       5 y_pred = classifier.predict(x_test)
#       6 print(y_pred)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     236             The fitted k-nearest neighbors classifier.
#     237         """
# --> 238         return self._fit(X, y)
#     239
#     240     def predict(self, X):
#
# ...

# %%
# !pip install pandas scikit-learn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import OneHotEncoder
# Import the metrics module
from sklearn.metrics import accuracy_score, classification_report

# Assuming 'df' is your DataFrame

# 1. Select numerical and categorical features
numerical_features = ["Age", "Gender", "Height (m)", "Max_BPM", "Avg_BPM", "Resting_BPM",
                      "Session_Duration (hours)", "Calories_Burned", "Fat_Percentage",
                      "Water_Intake (liters)", "Workout_Frequency (days/week)"]
categorical_features = ["Workout_Type", "Experience_Level"]

# 2. Create separate DataFrames
x_numerical = df[numerical_features]
x_categorical = df[categorical_features]

# 3. One-hot encode categorical features
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore') # sparse=False for KNeighborsRegressor
x_encoded = encoder.fit_transform(x_categorical)
x_encoded_df = pd.DataFrame(x_encoded, columns=encoder.get_feature_names_out(categorical_features))

# 4. Combine numerical and encoded features
x = pd.concat([x_numerical, x_encoded_df], axis=1)
y = df['BMI'].values

# 5. Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)


knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train, y_train)

#
y_pred = knn.predict(x_test)
print(y_pred)
print(y_test)

# print("Accuracy:",accuracy_score(y_test, y_pred.round().astype(int)))
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# ...
# [23.18  21.494 24.946 25.976 21.328 20.122 22.48  22.19  23.698 29.38
#  25.68  21.39  28.432 28.954 22.374 24.926 25.97  26.296 25.358 27.06
#  22.902 23.464 24.054 23.26  22.69  24.954 22.944 25.484 25.972 26.372
#  22.748 23.18  22.57  24.172 24.982 23.948 18.792 27.806 25.12  21.804
#  24.19  25.176 27.734 20.65  19.868 21.074 33.62  25.728 23.956 27.074
#  27.76  26.07  24.892 22.694 23.218 19.324 19.742 28.728 21.066 26.028
#  24.452 25.498 21.924 26.446 25.852 24.44  26.762 27.734 30.588 27.072
#  22.846 25.572 21.622 24.284 23.672 21.404 22.29  29.278 22.43  20.692
#  24.08  22.79  25.56  21.382 23.396 23.882 29.3   24.608 22.39  25.18
#  21.874 22.282 26.498 28.578 26.448 24.108 21.978 19.872 26.01  22.508
#  25.67  27.128 22.916 22.884 24.456 28.618 20.024 19.682 24.266 27.522
#  24.744 20.422 29.674 26.852 26.972 27.684 28.502 21.138 20.556 18.494
#  24.814 20.438 23.19  24.6   25.004 27.914 25.628 22.396 27.524 18.634
# ...
